# %%
import random

# %%
koszyk1 = ['Niemcy', 'Brazylia', 'Portugalia', 'Argentyna', 'Belgia', 'Polska', 'Francja']
koszyk2 = ['Hiszpania', 'Peru', 'Szwajcaria', 'Anglia', 'Kolumbia', 'Meksyk', 'Urugwaj', 'Chorwacja' ]
koszyk3 = ['Dania', 'Islandia', 'Kostaryka', 'Szwecja', 'Tunezja', 'Egipt', 'Senegal', 'Iran']
koszyk4 = ['Serbia', 'Nigeria', 'Australia', 'Japonia', 'Maroko', 'Panama', 'Korea Południowa', 'Arabia Saudyjska']
grupaa2 = random.choice(koszyk2)
grupaa3 = random.choice(koszyk3)
grupaa4 = random.choice(koszyk4)
grupab1 = random.choice(koszyk1)
grupab2 = random.choice(koszyk2)
grupab3 = random.choice(koszyk3)
grupab4 = random.choice(koszyk4)
while (grupab2) is (grupaa2):
        grupab2 = random.choice(koszyk2)        
while (grupab3) is (grupaa3):
        grupab3 = random.choice(koszyk3)
while (grupab4) is (grupaa4):
        grupacb = random.choice(koszyk4)        
grupac1 = random.choice(koszyk1)
grupac2 = random.choice(koszyk2)
grupac3 = random.choice(koszyk3)
grupac4 = random.choice(koszyk4)
while (grupac1) is (grupab1):
        grupac1 = random.choice(koszyk1)
while (grupac2) is (grupab2) or (grupac2) is (grupaa2):
        grupac2 = random.choice(koszyk2)      
while (grupac3) is (grupab3) or (grupac3) is (grupaa3):
        grupac3 = random.choice(koszyk3)
while (grupac4) is (grupab4) or (grupac4) is (grupaa4):
        grupac4 = random.choice(koszyk4)
grupad1 = random.choice(koszyk1)
grupad2 = random.choice(koszyk2)
grupad3 = random.choice(koszyk3)
grupad4 = random.choice(koszyk4)
while (grupad1) is (grupac1) or (grupad1) is (grupab1):
        grupad1 = random.choice(koszyk1)
while (grupad2) is (grupac2) or (grupad2) is (grupab2) or (grupad2) is (grupaa2):
        grupad2 = random.choice(koszyk2)      
while (grupad3) is (grupac3) or (grupad3) is (grupab3) or (grupad3) is (grupaa3):
        grupad3 = random.choice(koszyk3)    
while (grupad4) is (grupac4) or (grupad4) is (grupab4) or (grupad4) is (grupaa4):
        grupad4 = random.choice(koszyk4) 
grupae1 = random.choice(koszyk1)
grupae2 = random.choice(koszyk2)
grupae3 = random.choice(koszyk3)
grupae4 = random.choice(koszyk4)
while (grupae1) is (grupac1) or (grupae1) is (grupab1) or (grupae1) is (grupad1):
        grupae1 = random.choice(koszyk1)
while (grupae2) is (grupac2) or (grupae2) is (grupab2) or (grupae2) is (grupaa2) or (grupae2) is (grupad2):
        grupae2 = random.choice(koszyk2)      
while (grupae3) is (grupac3) or (grupae3) is (grupab3) or (grupae3) is (grupaa3) or (grupae3) is (grupad3):
        grupae3 = random.choice(koszyk3)    
while (grupae4) is (grupac4) or (grupae4) is (grupab4) or (grupae4) is (grupaa4) or (grupae4) is (grupad4):
        grupae4 = random.choice(koszyk4)          
grupaf1 = random.choice(koszyk1)
grupaf2 = random.choice(koszyk2)
grupaf3 = random.choice(koszyk3)
grupaf4 = random.choice(koszyk4)
while (grupaf1) is (grupac1) or (grupaf1) is (grupab1) or (grupaf1) is (grupad1) or (grupaf1) is (grupae1):
        grupaf1 = random.choice(koszyk1)
while (grupaf2) is (grupac2) or (grupaf2) is (grupab2) or (grupaf2) is (grupaa2) or (grupaf2) is (grupad2) or (grupaf2) is (grupae2):
        grupaf2 = random.choice(koszyk2)      
while (grupaf3) is (grupac3) or (grupaf3) is (grupab3) or (grupaf3) is (grupaa3) or (grupaf3) is (grupad3) or (grupaf3) is (grupae3):
        grupaf3 = random.choice(koszyk3)    
while (grupaf4) is (grupac4) or (grupaf4) is (grupab4) or (grupaf4) is (grupaa4) or (grupaf4) is (grupad4) or (grupaf4) is (grupae4):
        grupaf4 = random.choice(koszyk4)
grupag1 = random.choice(koszyk1)
grupag2 = random.choice(koszyk2)
grupag3 = random.choice(koszyk3)
grupag4 = random.choice(koszyk4)
while (grupag1) is (grupac1) or (grupag1) is (grupab1) or (grupag1) is (grupad1) or (grupag1) is (grupae1) or (grupag1) is (grupaf1):
        grupag1 = random.choice(koszyk1)
while (grupag2) is (grupac2) or (grupag2) is (grupab2) or (grupag2) is (grupaa2) or (grupag2) is (grupad2) or (grupag2) is (grupae2) or (grupag2) is (grupaf2):
        grupag2 = random.choice(koszyk2)      
while (grupag3) is (grupac3) or (grupag3) is (grupab3) or (grupag3) is (grupaa3) or (grupag3) is (grupad3) or (grupag3) is (grupae3) or (grupag3) is (grupaf3):
        grupag3 = random.choice(koszyk3)    
while (grupag4) is (grupac4) or (grupag4) is (grupab4) or (grupag4) is (grupaa4) or (grupag4) is (grupad4) or (grupag4) is (grupae4) or (grupag4) is (grupaf4):
        grupag4 = random.choice(koszyk4)
grupah1 = random.choice(koszyk1)
grupah2 = random.choice(koszyk2)
grupah3 = random.choice(koszyk3)
grupah4 = random.choice(koszyk4)
while (grupah1) is (grupac1) or (grupah1) is (grupab1) or (grupah1) is (grupad1) or (grupah1) is (grupae1) or (grupah1) is (grupaf1) or (grupah1) is (grupag1):
        grupah1 = random.choice(koszyk1)
while (grupah2) is (grupac2) or (grupah2) is (grupab2) or (grupah2) is (grupaa2) or (grupah2) is (grupad2) or (grupah2) is (grupae2) or (grupah2) is (grupaf2) or (grupah2) is (grupag2):
        grupah2 = random.choice(koszyk2)      
while (grupah3) is (grupac3) or (grupah3) is (grupab3) or (grupah3) is (grupaa3) or (grupah3) is (grupad3) or (grupah3) is (grupae3) or (grupah3) is (grupaf3) or (grupah3) is (grupag3):
        grupah3 = random.choice(koszyk3)    
while (grupah4) is (grupac4) or (grupah4) is (grupab4) or (grupah4) is (grupaa4) or (grupah4) is (grupad4) or (grupah4) is (grupae4) or (grupah4) is (grupaf4) or (grupah4) is (grupag4):
        grupah4 = random.choice(koszyk4)        

print('Zdrastwujcie druzja, witamy na losowaniu fazy grupowej finałów piłkarskich Mistrzostw Świata 2018,')
print ('które od będą się w Rosji, Ja się nazywam Włodzimierz Putin i poprowadzę dzisiejszą galę, zaczynamy losowanie :D')
print('Skład grupy A to: Rosja, '+(grupaa2)+', '+(grupaa3)+', '+(grupaa4))
print('Skład grupy B to: '+(grupab1)+', '+(grupab2)+', '+(grupab3)+', '+(grupab4))
print('Skład grupy C to: '+(grupac1)+', '+(grupac2)+', '+(grupac3)+', '+(grupac4))
print('Skład grupy D to: '+(grupad1)+', '+(grupad2)+', '+(grupad3)+', '+(grupad4))
print('Skład grupy E to: '+(grupae1)+', '+(grupae2)+', '+(grupae3)+', '+(grupae4))
print('Skład grupy F to: '+(grupaf1)+', '+(grupaf2)+', '+(grupaf3)+', '+(grupaf4))
print('Skład grupy G to: '+(grupag1)+', '+(grupag2)+', '+(grupag3)+', '+(grupag4))
print('Skład grupy H to: '+(grupah1)+', '+(grupah2)+', '+(grupah3)+', '+(grupah4))
# Out:
# Zdrastwujcie druzja, witamy na losowaniu fazy grupowej finałów piłkarskich Mistrzostw Świata 2018,
# które od będą się w Rosji, Ja się nazywam Włodzimierz Putin i poprowadzę dzisiejszą galę, zaczynamy losowanie :D
# Skład grupy A to: Rosja, Szwajcaria, Egipt, Korea Południowa
# Skład grupy B to: Argentyna, Meksyk, Dania, Australia
# Skład grupy C to: Portugalia, Anglia, Iran, Arabia Saudyjska
# Skład grupy D to: Brazylia, Hiszpania, Kostaryka, Panama
# Skład grupy E to: Polska, Urugwaj, Senegal, Japonia
# Skład grupy F to: Niemcy, Kolumbia, Tunezja, Maroko
# Skład grupy G to: Francja, Peru, Islandia, Serbia
# Skład grupy H to: Belgia, Chorwacja, Szwecja, Nigeria

# %%
grupaa1 = 'Rosja'
Grupa_A = [grupaa1, grupaa2, grupaa3, grupaa4]
Grupa_B = [grupab1, grupab2, grupab3, grupab4]
Grupa_C = [grupac1, grupac2, grupac3, grupac4]
Grupa_D = [grupad1, grupad2, grupad3, grupad4]
Grupa_E = [grupae1, grupae2, grupae3, grupae4]
Grupa_F = [grupaf1, grupaf2, grupaf3, grupaf4]
Grupa_G = [grupag1, grupag2, grupag3, grupag4]
Grupa_H = [grupah1, grupah2, grupah3, grupah4]

Zwyciezca_A = random.choice(Grupa_A)
Drugi_A = random.choice(Grupa_A)
while Drugi_A is Zwyciezca_A:
    Drugi_A = random.choice(Grupa_A)
    
Zwyciezca_B = random.choice(Grupa_B)
Drugi_B = random.choice(Grupa_B)
while Drugi_B is Zwyciezca_B:
    Drugi_B = random.choice(Grupa_B)    
    
Zwyciezca_C = random.choice(Grupa_C)
Drugi_C = random.choice(Grupa_C)
while Drugi_C is Zwyciezca_C:
    Drugi_C = random.choice(Grupa_C)  
    
Zwyciezca_D = random.choice(Grupa_D)
Drugi_D = random.choice(Grupa_D)
while Drugi_D is Zwyciezca_D:
    Drugi_D = random.choice(Grupa_D)      
    
Zwyciezca_E = random.choice(Grupa_E)
Drugi_E = random.choice(Grupa_E)
while Drugi_E is Zwyciezca_E:
    Drugi_E = random.choice(Grupa_E)
    
Zwyciezca_F = random.choice(Grupa_F)
Drugi_F = random.choice(Grupa_F)
while Drugi_F is Zwyciezca_F:
    Drugi_F = random.choice(Grupa_F)
    
Zwyciezca_G = random.choice(Grupa_G)
Drugi_G = random.choice(Grupa_G)
while Drugi_G is Zwyciezca_G:
    Drugi_G = random.choice(Grupa_G)      

Zwyciezca_H = random.choice(Grupa_H)
Drugi_H = random.choice(Grupa_H)
while Drugi_H is Zwyciezca_H:
    Drugi_H = random.choice(Grupa_H)      
    
print('O to pary 1/8 finału:')
print((Zwyciezca_A)+' vs '+(Drugi_B))
print((Zwyciezca_C)+' vs '+(Drugi_D))
print((Zwyciezca_E)+' vs '+(Drugi_F))
print((Zwyciezca_F)+' vs '+(Drugi_H))
print((Zwyciezca_B)+' vs '+(Drugi_A))
print((Zwyciezca_D)+' vs '+(Drugi_C))
print((Zwyciezca_F)+' vs '+(Drugi_E))
print((Zwyciezca_H)+' vs '+(Drugi_G))
# Out:
# O to pary 1/8 finału:
# Rosja vs Australia
# Arabia Saudyjska vs Brazylia
# Urugwaj vs Tunezja
# Maroko vs Belgia
# Meksyk vs Korea Południowa
# Kostaryka vs Anglia
# Maroko vs Senegal
# Chorwacja vs Islandia

# %%
import string

koszyki = dict(
koszyk1= ['Niemcy', 'Brazylia', 'Portugalia', 'Argentyna', 'Belgia', 'Polska', 'Francja'],
koszyk2= ['Hiszpania', 'Peru', 'Szwajcaria', 'Anglia', 'Kolumbia', 'Meksyk', 'Urugwaj', 'Chorwacja' ],
koszyk3= ['Dania', 'Islandia', 'Kostaryka', 'Szwecja', 'Tunezja', 'Egipt', 'Senegal', 'Iran'],
koszyk4= ['Serbia', 'Nigeria', 'Australia', 'Japonia', 'Maroko', 'Panama', 'Korea Południowa', 'Arabia Saudyjska'],
)

nazwy_koszyków = sorted(koszyki.keys())
grupy = {letter:[] for letter in list(string.ascii_uppercase)[:8]}

for index, litera_grupy in enumerate(sorted(grupy.keys())):
    for nazwa_koszyku in nazwy_koszyków:
        if index == 0 and litera_grupy == 'A' and nazwa_koszyku == 'koszyk1':
            grupy['A'].append('Rosja')
        else:
            wylosowana_drużyna = random.choice(koszyki[nazwa_koszyku])
            grupy[litera_grupy].append(wylosowana_drużyna)
            koszyki[nazwa_koszyku].remove(wylosowana_drużyna)
    
print('добро пожаловать на ничью группового этапа футбольных финалов чемпионата мира 2018 года, \n Поскольку я буду в России, меня называют Владимиром Путиным, и я приведу сегодня шоу, мы начнем рисовать \n')

for nazwa_grupy, zespoły in grupy.items():
    print('Skład grupy {} to: '.format(nazwa_grupy) +', '.join(zespoły))
# Out:
# добро пожаловать на ничью группового этапа футбольных финалов чемпионата мира 2018 года,
#  Поскольку я буду в России, меня называют Владимиром Путиным, и я приведу сегодня шоу, мы начнем рисовать
#
# Skład grupy A to: Rosja, Hiszpania, Egipt, Arabia Saudyjska
# Skład grupy B to: Argentyna, Peru, Tunezja, Serbia
# Skład grupy C to: Niemcy, Anglia, Szwecja, Nigeria
# Skład grupy D to: Francja, Urugwaj, Iran, Korea Południowa
# Skład grupy E to: Polska, Kolumbia, Kostaryka, Japonia
# Skład grupy F to: Belgia, Chorwacja, Islandia, Australia
# Skład grupy G to: Portugalia, Szwajcaria, Dania, Panama
# Skład grupy H to: Brazylia, Meksyk, Senegal, Maroko
